# %% [markdown]
# <a href="https://colab.research.google.com/github/jotagectti/PYTHON-y-R-BigData-Structuralia/blob/main/Gr%C3%A1ficos_II_y_programaci%C3%B3n_en_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# data("ToothGrowth")

# %%
# %%R
# head(ToothGrowth)
# Out:
#    len supp dose
# 1  4.2   VC  0.5
# 2 11.5   VC  0.5
# 3  7.3   VC  0.5
# 4  5.8   VC  0.5
# 5  6.4   VC  0.5
# 6 10.0   VC  0.5

# %%
# %%R
# tail(ToothGrowth)
# Out:
#     len supp dose
# 55 24.8   OJ    2
# 56 30.9   OJ    2
# 57 26.4   OJ    2
# 58 27.3   OJ    2
# 59 29.4   OJ    2
# 60 23.0   OJ    2

# %%
# %%R
# str(ToothGrowth)
# Out:
# 'data.frame':	60 obs. of  3 variables:
#  $ len : num  4.2 11.5 7.3 5.8 6.4 10 11.2 11.2 5.2 7 ...
#  $ supp: Factor w/ 2 levels "OJ","VC": 2 2 2 2 2 2 2 2 2 2 ...
#  $ dose: num  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 ...

# %%
# %%R
# plot(x=ToothGrowth$len,y=ToothGrowth$dose,col="purple")

# %%
# %%R
# plot(x=ToothGrowth$len,y=ToothGrowth$dose,col=ToothGrowth$supp)
